# %% [markdown]
# The goal of this project is to use data science techniques and machine learning to predict future pricing/behavior for a given stock. Primarily I intend for this to use some form of forecasting.
#
# Although I am aware of the random nature of the stock market, I hope to be somewhat able to accurately predict stocks given historic data and trends.

# %%
from pathLib import Path
import numpy as np
import pandas as pd
# still working on which libraries I need
