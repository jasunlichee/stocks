# %%
from pathlib import Path
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# Ideas:
#
# Recent price change in last 1, 5, 10, 20 days
# Moving average distance over last 5, 10, 20, 50 days
# Volatility over last 5, 10, 20 days
#
# 1. take out 20% of the data (test)
#
# 2. Write generic curate function to curate dataset (training)
#
# 3. add the file name as a 'Ticker' column
#
# 4. merge into one dataset
#
# 5. sort by 'Date', then 'Ticker'
#
# 6. train the model

# %%
LOOKBACK = 50

FEATURE_COLUMNS = [
    "return_1",
    "return_5",
    "return_10",
    "return_20",
    "ma_dist_5",
    "ma_dist_10",
    "ma_dist_20",
    "ma_dist_50",
    "volatility_5",
    "volatility_10",
    "volatility_20",
    "volume_change",
    "volume_ratio_20",
    "intraday_return",
    "range_pct",
    "close_position",
]


def add_features(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df = df.sort_values("Date").reset_index(drop=True)

    # Returns / momentum
    df["return_1"] = df["Close"].pct_change(1)
    df["return_5"] = df["Close"].pct_change(5)
    df["return_10"] = df["Close"].pct_change(10)
    df["return_20"] = df["Close"].pct_change(20)

    # Moving average distance
    ma_5 = df["Close"].rolling(5).mean()
    ma_10 = df["Close"].rolling(10).mean()
    ma_20 = df["Close"].rolling(20).mean()
    ma_50 = df["Close"].rolling(50).mean()

    df["ma_dist_5"] = (df["Close"] - ma_5) / ma_5
    df["ma_dist_10"] = (df["Close"] - ma_10) / ma_10
    df["ma_dist_20"] = (df["Close"] - ma_20) / ma_20
    df["ma_dist_50"] = (df["Close"] - ma_50) / ma_50

    # Volatility
    df["volatility_5"] = df["return_1"].rolling(5).std()
    df["volatility_10"] = df["return_1"].rolling(10).std()
    df["volatility_20"] = df["return_1"].rolling(20).std()

    # Volume features
    df["volume_change"] = df["Volume"].pct_change(1)
    volume_ma_20 = df["Volume"].rolling(20).mean()
    df["volume_ratio_20"] = df["Volume"] / volume_ma_20

    # Intraday structure
    df["intraday_return"] = (df["Close"] - df["Open"]) / df["Open"]
    df["range_pct"] = (df["High"] - df["Low"]) / df["Close"]

    day_range = df["High"] - df["Low"]
    df["close_position"] = np.where(
        day_range != 0,
        (df["Close"] - df["Low"]) / day_range,
        0.5
    )

    # Target: does tomorrow close higher than today?
    df["target"] = (df["Close"].shift(-1) > df["Close"]).astype(int)

    return df


def curate_stock_file(
    input_csv: str | Path,
    train_output_csv: str | Path,
    test_output_csv: str | Path,
    test_ratio: float = 0.20,
    lookback: int = LOOKBACK,
) -> tuple[pd.DataFrame, pd.DataFrame]:
    input_csv = Path(input_csv)
    train_output_csv = Path(train_output_csv)
    test_output_csv = Path(test_output_csv)

    df = pd.read_csv(input_csv)
    df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")
    df = df.sort_values("Date").reset_index(drop=True)

    n = len(df)
    split_idx = int(n * (1 - test_ratio))

    if split_idx <= lookback:
        raise ValueError(
            f"{input_csv.name} does not have enough rows for a {lookback}-day lookback."
        )

    train_raw = df.iloc[:split_idx].copy()
    test_raw = df.iloc[split_idx:].copy()

    # Curate training set normally.
    train_curated = add_features(train_raw)

    # Drop first `lookback` rows (insufficient history)
    # and last row (no next-day target inside training set).
    train_curated = train_curated.iloc[lookback:-1].reset_index(drop=True)

    # For test: prepend last `lookback` rows from training so early test rows
    # can compute rolling features without leaking future test information backward.
    history = train_raw.iloc[-lookback:].copy()
    test_with_history = pd.concat([history, test_raw], ignore_index=True)

    test_curated = add_features(test_with_history)

    # Keep only rows that actually belong to the test period.
    first_test_date = test_raw["Date"].iloc[0]
    test_curated = test_curated[test_curated["Date"] >= first_test_date].copy()

    # Drop the last row of the test set too, because it has no t+1 target
    # inside the file.
    test_curated = test_curated.iloc[:-1].reset_index(drop=True)

    # Add ticker from filename if desired
    ticker = input_csv.stem
    train_curated["Ticker"] = ticker
    test_curated["Ticker"] = ticker

    # Reorder columns a bit
    base_columns = ["Date", "Ticker", "Open", "High", "Low", "Close", "Volume"]
    ordered_columns = base_columns + FEATURE_COLUMNS + ["target"]

    train_curated = train_curated[ordered_columns]
    test_curated = test_curated[ordered_columns]

    train_output_csv.parent.mkdir(parents=True, exist_ok=True)
    test_output_csv.parent.mkdir(parents=True, exist_ok=True)

    train_curated.to_csv(train_output_csv, index=False)
    test_curated.to_csv(test_output_csv, index=False)

    return train_curated, test_curated


def curate_directory(
    raw_dir: str | Path,
    curated_dir: str | Path,
    test_ratio: float = 0.20,
    lookback: int = LOOKBACK,
) -> None:
    raw_dir = Path(raw_dir)
    curated_dir = Path(curated_dir)

    train_dir = curated_dir / "train"
    test_dir = curated_dir / "test"

    csv_files = sorted(raw_dir.glob("*.csv"))

    for csv_file in csv_files:
        train_output_csv = train_dir / csv_file.name
        test_output_csv = test_dir / csv_file.name

        try:
            train_df, test_df = curate_stock_file(
                input_csv=csv_file,
                train_output_csv=train_output_csv,
                test_output_csv=test_output_csv,
                test_ratio=test_ratio,
                lookback=lookback,
            )
            print(
                f"Processed {csv_file.name}: "
                f"train={len(train_df)} rows, test={len(test_df)} rows"
            )
        except Exception as e:
            print(f"Skipped {csv_file.name}: {e}")


if __name__ == "__main__":
    raw_dir = "stock_market_data/sp500/raw_csv"
    curated_dir = "stock_market_data/sp500/curated_csv"

    curate_directory(raw_dir, curated_dir)
# Out:
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed A.csv: train=4592 rows, test=1160 rows
# Processed AAL.csv: train=3415 rows, test=866 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AAP.csv: train=4185 rows, test=1059 rows
# Processed AAPL.csv: train=8421 rows, test=2117 rows
# Processed ABBV.csv: train=1953 rows, test=500 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ABC.csv: train=5527 rows, test=1394 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ABMD.csv: train=7081 rows, test=1783 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ABT.csv: train=8571 rows, test=2155 rows
# Processed ACN.csv: train=4257 rows, test=1076 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ADI.csv: train=8571 rows, test=2155 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ADM.csv: train=8571 rows, test=2155 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ADP.csv: train=8571 rows, test=2155 rows
# Processed ADSK.csv: train=7501 rows, test=1888 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AEE.csv: train=4971 rows, test=1255 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AEP.csv: train=10633 rows, test=2671 rows
# Processed AIZ.csv: train=3746 rows, test=949 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AJG.csv: train=7709 rows, test=1939 rows
# Processed AKAM.csv: train=4603 rows, test=1163 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ALB.csv: train=5752 rows, test=1450 rows
# Processed ALGN.csv: train=4351 rows, test=1100 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ALK.csv: train=8571 rows, test=2155 rows
# Processed ALLE.csv: train=1775 rows, test=456 rows
# Processed ALTR.csv: train=978 rows, test=257 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AMAT.csv: train=8571 rows, test=2155 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AMD.csv: train=8571 rows, test=2155 rows
# Processed AME.csv: train=7693 rows, test=1935 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AMGN.csv: train=7913 rows, test=1990 rows
# Processed AMP.csv: train=3421 rows, test=868 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AMT.csv: train=4941 rows, test=1247 rows
# Processed AMZN.csv: train=5099 rows, test=1287 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ANET.csv: train=1665 rows, test=429 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AON.csv: train=8529 rows, test=2144 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AOS.csv: train=7854 rows, test=1976 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed APA.csv: train=8741 rows, test=2197 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed APD.csv: train=8571 rows, test=2155 rows
# Processed APH.csv: train=6214 rows, test=1566 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ARE.csv: train=5093 rows, test=1285 rows
# Processed ATVI.csv: train=5818 rows, test=1467 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AVB.csv: train=5741 rows, test=1448 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AVY.csv: train=10000 rows, test=2512 rows
# Processed AWK.csv: train=2898 rows, test=737 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed AXP.csv: train=10144 rows, test=2548 rows
# Processed AZO.csv: train=6338 rows, test=1597 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BA.csv: train=10633 rows, test=2671 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BAC.csv: train=10000 rows, test=2512 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BAX.csv: train=8245 rows, test=2073 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BBY.csv: train=7541 rows, test=1898 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BDX.csv: train=10000 rows, test=2512 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BEN.csv: train=7858 rows, test=1977 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BF-A.csv: train=9960 rows, test=2502 rows
# Processed BHI.csv: train=813 rows, test=216 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BIIB.csv: train=6245 rows, test=1573 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BIO.csv: train=8581 rows, test=2158 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BK.csv: train=9960 rows, test=2502 rows
# Processed BLK.csv: train=4619 rows, test=1167 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BMRA.csv: train=7665 rows, test=1928 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BMY.csv: train=10144 rows, test=2548 rows
# Processed BR.csv: train=3117 rows, test=792 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BRK-A.csv: train=8571 rows, test=2155 rows
# Processed BSHI.csv: train=4681 rows, test=1183 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BSX.csv: train=6109 rows, test=1539 rows
# Processed BWA.csv: train=5858 rows, test=1477 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed BXP.csv: train=5081 rows, test=1282 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed C.csv: train=9218 rows, test=2317 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CAG.csv: train=8571 rows, test=2155 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CAH.csv: train=7886 rows, test=1984 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CAT.csv: train=10633 rows, test=2671 rows
# Processed CB.csv: train=5937 rows, test=1496 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CCI.csv: train=4845 rows, test=1224 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CDE.csv: train=8571 rows, test=2155 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CDNS.csv: train=7109 rows, test=1789 rows
# Processed CF.csv: train=3441 rows, test=872 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CFG.csv: train=1605 rows, test=413 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CHD.csv: train=8571 rows, test=2155 rows
# Processed CHRW.csv: train=5013 rows, test=1266 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CHTR.csv: train=2555 rows, test=651 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CINF.csv: train=8571 rows, test=2155 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CL.csv: train=9961 rows, test=2502 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CLX.csv: train=10000 rows, test=2512 rows
# Processed CME.csv: train=3980 rows, test=1007 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CMG.csv: train=3349 rows, test=849 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CMI.csv: train=10000 rows, test=2512 rows
# Processed CNC.csv: train=4177 rows, test=1057 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CNP.csv: train=10633 rows, test=2671 rows
# Processed CNWT.csv: train=4982 rows, test=1258 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed COO.csv: train=7994 rows, test=2011 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed COP.csv: train=8209 rows, test=2064 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed COST.csv: train=7295 rows, test=1836 rows
# Processed COTY.csv: train=1863 rows, test=478 rows
# Processed COWN.csv: train=3256 rows, test=826 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CPB.csv: train=10000 rows, test=2512 rows
# Processed CPICQ.csv: train=8092 rows, test=2035 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CPRT.csv: train=5738 rows, test=1447 rows
# Processed CRM.csv: train=3670 rows, test=930 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CSCO.csv: train=6564 rows, test=1653 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CTAS.csv: train=7877 rows, test=1982 rows
# Processed CTQ.csv: train=2268 rows, test=579 rows
# Processed CTSH.csv: train=4878 rows, test=1232 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed CUK.csv: train=4405 rows, test=1113 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed D.csv: train=8571 rows, test=2155 rows
# Processed DAL.csv: train=3094 rows, test=786 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed DE.csv: train=10144 rows, test=2548 rows
# Processed DFS.csv: train=3071 rows, test=780 rows
# Processed DG.csv: train=2582 rows, test=658 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed DGX.csv: train=5181 rows, test=1308 rows
# Processed DHI.csv: train=6099 rows, test=1537 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed DIS.csv: train=10633 rows, test=2671 rows
# Processed DLTR.csv: train=5543 rows, test=1398 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed DOV.csv: train=8571 rows, test=2155 rows
# Processed DPZ.csv: train=3660 rows, test=927 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed DRE.csv: train=5833 rows, test=1470 rows
# Processed DRI.csv: train=5508 rows, test=1389 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed DTE.csv: train=10633 rows, test=2671 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed DVA.csv: train=5410 rows, test=1365 rows
# Processed DXCM.csv: train=3507 rows, test=889 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed EA.csv: train=6647 rows, test=1674 rows
# Processed EBAY.csv: train=4825 rows, test=1218 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ECL.csv: train=10000 rows, test=2512 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ED.csv: train=10633 rows, test=2671 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed EFX.csv: train=8571 rows, test=2155 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed EIX.csv: train=9960 rows, test=2502 rows
# Processed EL.csv: train=5400 rows, test=1362 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed EMN.csv: train=5790 rows, test=1460 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed EMR.csv: train=10144 rows, test=2548 rows
# Processed ENS.csv: train=3649 rows, test=924 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed EOG.csv: train=6639 rows, test=1672 rows
# Processed EQIX.csv: train=4445 rows, test=1123 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed EQR.csv: train=5859 rows, test=1477 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ES.csv: train=10000 rows, test=2512 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed ESS.csv: train=5694 rows, test=1436 rows
# Processed EW.csv: train=4521 rows, test=1143 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# ...
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed SLB.csv: train=8209 rows, test=2064 rows
# Processed SLG.csv: train=5048 rows, test=1274 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed SNPS.csv: train=6155 rows, test=1551 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed SO.csv: train=8209 rows, test=2064 rows
# Processed SONC.csv: train=6356 rows, test=1601 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed SPG.csv: train=5790 rows, test=1460 rows
# Processed SRE.csv: train=4873 rows, test=1231 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed SRG.csv: train=1449 rows, test=374 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed STT.csv: train=8571 rows, test=2155 rows
# Processed STX.csv: train=3977 rows, test=1007 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed STZ-B.csv: train=9995 rows, test=2511 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed SWK.csv: train=8571 rows, test=2155 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed SWKS.csv: train=7665 rows, test=1928 rows
# Processed SYF.csv: train=1635 rows, test=421 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed SYK.csv: train=8571 rows, test=2155 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed T.csv: train=7825 rows, test=1969 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed TAP.csv: train=9533 rows, test=2396 rows
# Processed TCYSF.csv: train=1921 rows, test=492 rows
# Processed TEL.csv: train=3071 rows, test=780 rows
# Processed TIME.csv: train=124 rows, test=43 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed TJX.csv: train=7099 rows, test=1787 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed TMO.csv: train=8571 rows, test=2155 rows
# Processed TMUS.csv: train=3102 rows, test=788 rows
# Processed TRAUF.csv: train=3260 rows, test=827 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed TROW.csv: train=7349 rows, test=1850 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed TRV.csv: train=9445 rows, test=2374 rows
# Processed TSCO.csv: train=5753 rows, test=1451 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed TSN.csv: train=8571 rows, test=2155 rows
# Processed TTWO.csv: train=5117 rows, test=1291 rows
# Processed TW.csv: train=693 rows, test=186 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed TWTR.csv: train=1780 rows, test=457 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed TXN.csv: train=10144 rows, test=2548 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed TXT.csv: train=10000 rows, test=2512 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed TYL.csv: train=8571 rows, test=2155 rows
# Processed UA.csv: train=1304 rows, test=338 rows
# Processed UAL.csv: train=3343 rows, test=848 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed UDR.csv: train=8571 rows, test=2155 rows
# Processed UEEC.csv: train=3137 rows, test=797 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed UHS.csv: train=8306 rows, test=2089 rows
# Processed ULTA.csv: train=2997 rows, test=761 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed UNM.csv: train=7227 rows, test=1819 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# Processed UNP.csv: train=8613 rows, test=2165 rows
# Processed UPS.csv: train=4597 rows, test=1161 rows
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
# /var/folders/y3/yhcxkdhs2pj8yc1d275hmgbc0000gn/T/ipykernel_63188/4278513264.py:83: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])
